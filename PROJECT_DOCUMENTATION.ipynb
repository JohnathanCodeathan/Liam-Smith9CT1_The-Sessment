# %% [markdown]
# # The documentation

# %% [markdown]
# ## Identifying and Defining

# %% [markdown]
# ### Mindmap
# Since I'm bad at making decision, I charted out the possible options for what topic I could choose here:
#
# ![Since I'm bad at making decision, I charted out the possible options for what topic I could choose here:](John_Mindmap.png)

# %% [markdown]
# ### Define your purpose
# I finally decided on the topic of "Is it harder to achieve financial security today compared to the past?"

# %% [markdown]
# ### Requirements Outline
# Functional Requirements:
# - Data Loading: My program should be able to load and process all files that it needs to utilise. However, if there is an error in file loading, the program will inform the user about the error, and if it's a problem with the whole file (like file formatting or a missing file), it will inform the user of the error, and not display the file to the user.
# - Data Cleaning: The system will need to handle missing values as leaving them blank will skew results and charts, and will handle missing values by informing the user of the missing values, replacing those missing values with a placeholder value (Like 'null', or 'error'), and ask the user to fix those missing values. Additionally, the program should be able to allow the user to filter data to hide unnecessary data points based on certain characteristics, sort data by changing the order of the data by certain qualities, and group data by counting how many data points fit into certain ranges or categories. Those certain characteristics, qualities, and ranges can all be decided by the user.
# - Data Analysis: The program will need to allow for most common and the majority of useful kinds of statistical analysis, like mean, mode, median, range, standard deviation, and adding and subtracting various values because my program will turn into a big budgeting activity.
# - Data Visualisation: My system should be able to utilise both Pandas and Matplotlib to visualise my data in various formats. This mainly includes tables, line graphs, bar charts, and scatter plots.
# - Data Reporting: The system should be able to output visualisations, data, error messages and a User Interface that allows the user to select what they wish to do within the program. Additionally, the final data set should be stored in a .csv file somewhere within the directory of the wider project.
#
# Non-functional Requirements:
# - Usability:
# - Reliability:
# - Security (If I have time, not promised as of now):

# %% [markdown]
# ## Researching and planning

# %% [markdown]
# ### Researching my topic
# [Abc article on the issue](https://www.abc.net.au/news/2025-05-07/can-albanese-government-fix-the-economy-four-corners/105260320)
#
# [ABC interviews the reserve bank about the issue](https://www.abc.net.au/news/2025-11-10/rba-warns-economic-growth-could-stay-in-slow-lane-rates/105989680)
#
# [The Salvation Army's take on the cost of living crisis](https://www.salvationarmy.org.au/red-shield-appeal/the-cost-of-living-crisis-in-australia/)
#
# [Commonwealth bank talking about rising groceries cost](https://www.commbank.com.au/articles/newsroom/2026/01/groceries-stand-out-as-young-aussies-feel-rising-costs.html)
#
# [9news talking about rising groceries cost](https://www.9news.com.au/national/groceries-prices-inflation-coles-woolies-supermarket-prices/a0b3c54b-ac98-41cd-9132-879fe1663b42)
#
# [ABC news talking about how buying a home is hard](https://www.abc.net.au/news/2022-05-19/housing-buy-home-millennial-boomer-interest-rates-prices/101060862)

# %% [markdown]
# ### Data Dictionary
# | Field | Data Type | Format For Display | Description | Validation |
# | ----- | --------- | ------------------ | ----------- | ---------- |
# | averagein | float64 | NN.NN | The monthly average income of the year | Must be a decimal number to 2 decimal places |
# | year | float64 | NNNN | The year | Must be a 4 digit number |
# | mortgagerent | float64 | NN.NN | The average mortgage/rent/house payment per month | Must be a decimal number to 2 decimal places |
# | groceries | float64 | NN.NN | The average grocery cost per month | Must be a decimal number to 2 decimal places |
# | electricity | float64 | NN.NN | The average electricity cost per month | Must be a decimal number to 2 decimal places |
# | water | float64 | NN.NN | The average water cost per month | Must be a decimal number to 2 decimal places |
# | costtot | float64 | NN.NN | The total cost for all the expenses | Must be a decimal number to 2 decimal places |
# | savtot | float64 | NN.NN | Average income - costtot to determine how much people save | Must be a decimal number to 2 decimal places |
# | todcosttot | float64 | NN.NN | total costs adjusted to todays aussie dollar and inflation | Must be a decimal number to 2 decimal places |
# | todincome | float64 | NN.NN | Total income adjusted for inflation today | Must be a decimal number to 2 decimal place |
# | Todsav | float64 | NN.NN | Savings adjusted for inflation today | Must be a decimal number to 2 decimal places |
